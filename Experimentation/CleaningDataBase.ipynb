# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
import os

paths = []
direc = 'DataBaseCustom/DATASET/TEST'
for pose in os.listdir(direc):
    temp = []
    for path in os.listdir(direc + '/' + pose):
        temp.append(path)
    paths.append(temp)
print(paths)
# Out:
# [['00000000.jpg', '00000001.jpg', '00000002.jpeg', '00000003.jpg', '00000004.jpg', '00000005.jpg', '00000006.png', '00000007.jpg', '00000008.jpg', '00000009.jpg', '00000010.jpg', '00000011.jpg', '00000012.jpg', '00000013.jpg', '00000014.jpg', '00000015.jpg', '00000016.jpg', '00000018.jpg', '00000019.jpg', '00000020.png', '00000021.png', '00000022.jpg', '00000023.jpg', '00000024.jpg', '00000025.jpg', '00000027.jpg', '00000028.jpg', '00000029.jpg', '00000030.jpg', '00000031.jpg', '00000032.jpeg', '00000034.jpg', '00000036.jpg', '00000038.png', '00000039.jpg', '00000040.jpg', '00000041.jpg', '00000042.jpg', '00000045.jpg', '00000046.jpg', '00000047.png', '00000049.jpg', '00000050.jpg', '00000052.jpg', '00000053.png', '00000054.jpg', '00000055.jpg', '00000056.jpg', '00000057.jpg', '00000058.jpg', '00000059.jpg', '00000060.jpg', '00000062.jpg', '00000063.jpg', '00000067.jpg', '00000068.jpg', '00000069.jpg', '00000071.jpg', '00000072.jpg', '00000073.jpg', '00000074.jpg', '00000076.jpg', '0
# ...

# %%
import PIL
import io
for j, pose in enumerate(os.listdir(direc)):
    temp = paths[j]
    for i, path in enumerate(temp):
        with open(direc + '/' + pose + '/' + path, 'rb') as f:
            print(j, i, path)
            img = PIL.Image.open(io.BytesIO(f.read()))
# Out:
# 0 0 00000000.jpg
# 0 1 00000001.jpg
# 0 2 00000002.jpeg
# 0 3 00000003.jpg
# 0 4 00000004.jpg
# 0 5 00000005.jpg
# 0 6 00000006.png
# 0 7 00000007.jpg
# 0 8 00000008.jpg
# 0 9 00000009.jpg
# 0 10 00000010.jpg
# 0 11 00000011.jpg
# 0 12 00000012.jpg
# 0 13 00000013.jpg
# 0 14 00000014.jpg
# 0 15 00000015.jpg
# 0 16 00000016.jpg
# 0 17 00000018.jpg
# 0 18 00000019.jpg
# 0 19 00000020.png
# 0 20 00000021.png
# 0 21 00000022.jpg
# 0 22 00000023.jpg
# 0 23 00000024.jpg
# 0 24 00000025.jpg
# 0 25 00000027.jpg
# 0 26 00000028.jpg
# 0 27 00000029.jpg
# 0 28 00000030.jpg
# 0 29 00000031.jpg
# 0 30 00000032.jpeg
# 0 31 00000034.jpg
# 0 32 00000036.jpg
# 0 33 00000038.png
# 0 34 00000039.jpg
# 0 35 00000040.jpg
# 0 36 00000041.jpg
# 0 37 00000042.jpg
# 0 38 00000045.jpg
# 0 39 00000046.jpg
# 0 40 00000047.png
# 0 41 00000049.jpg
# 0 42 00000050.jpg
# 0 43 00000052.jpg
# 0 44 00000053.png
# 0 45 00000054.jpg
# 0 46 00000055.jpg
# 0 47 00000056.jpg
# 0 48 00000057.jpg
# 0 49 00000058.jpg
# ...
